# %% [markdown]
# <center><h3 style='color:red'>Keras | CNN Dog or Cat Classification</h3></center>
#
# ### Table:
# * **Introduction**
# * **Configuration**
# * **Read & Preprocessing the Data**
# * **CNN Network**
#     * **Training**
# * **Evaluation**
# * **Results**
# * **Testing Visualization**
# * **Other Solutions (TL)**
#
# <hr>
#
# **NEW IN VERSION 7:**
#    * Use ImageDataGenerator to read and preprocess the images directly.
#    * Different custom CNN network.
#    * Add EarlyStoping callback.
#    * Add comments and table.

# %% [markdown]
# ## Introduction
#
# **objective: Distinguish images of dogs from cats** using custom CNN network using keras.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

from glob import glob

import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical

from keras.models import Sequential, load_model, Model
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout
from keras.layers import Dense, Flatten
from keras.callbacks import EarlyStopping


import cv2
# Out:
# Using TensorFlow backend.

# %%
import os
print(os.listdir('../input'))
# Out:
# ['cat-and-dog', 'dogs-vs-cats-redux-kernels-edition']

# %% [markdown]
# ## Configuration

# %%
category = ["cats", "dogs"]

EPOCHS                  = 50
IMGSIZE                 = 128
CHANNELS                = 1 # grayscale
BATCH_SIZE              = 32
STOPPING_PATIENCE       = 8
VERBOSE                 = 1
MODEL_NAME              = 'cnn_50epochs_imgsize128.h5'
OPTIMIZER               = 'adam'
TRAINING_DIR            = '../input/cat-and-dog/training_set/training_set'
TEST_DIR                = '../input/cat-and-dog/test_set/test_set'

# %% [markdown]
# ## Read & Preprocessing Data

# %%
generator = ImageDataGenerator(rescale=1./255, 
                               shear_range=0.15, 
                               zoom_range=0.2, 
                               horizontal_flip=True
                              ) 

train_data = generator.flow_from_directory( directory=TRAINING_DIR, 
                                            target_size=(IMGSIZE, IMGSIZE),
                                            color_mode='grayscale',
                                            classes=category, 
                                            batch_size=BATCH_SIZE, 
                                            )


test_data = generator.flow_from_directory( directory=TEST_DIR, 
                                           target_size=(IMGSIZE, IMGSIZE), 
                                           color_mode='grayscale',
                                           classes=category, 
                                           batch_size=BATCH_SIZE,
                                           shuffle=False
                                           )
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %% [markdown]
# ## CNN Network

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMGSIZE, IMGSIZE, CHANNELS)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dropout(0.25))

model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 126, 126, 32)      320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 124, 124, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 62, 62, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 58, 58, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 29, 29, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 29, 29, 64)        256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 53824)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 53824)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 107650
# =================================================================
# Total params: 173,026
# Trainable params: 172,834
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
es = EarlyStopping(patience=STOPPING_PATIENCE, 
                   monitor='val_accuracy', 
                   mode='max', 
                   verbose=1, 
                   restore_best_weights=True)

history = model.fit_generator(train_data, 
                              epochs=EPOCHS, 
                              validation_data=test_data,
                              shuffle=True,
                              callbacks=[es]
                             )
# Out:
# Epoch 1/50
# 251/251 [==============================] - 71s 284ms/step - loss: 2.4125 - accuracy: 0.5786 - val_loss: 7.7348 - val_accuracy: 0.4998
# Epoch 2/50
# 251/251 [==============================] - 44s 175ms/step - loss: 1.8063 - accuracy: 0.5903 - val_loss: 1.6112 - val_accuracy: 0.5744
# Epoch 3/50
# 251/251 [==============================] - 43s 173ms/step - loss: 1.2613 - accuracy: 0.6408 - val_loss: 0.3904 - val_accuracy: 0.6401
# Epoch 4/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.8755 - accuracy: 0.6762 - val_loss: 0.7409 - val_accuracy: 0.6980
# Epoch 5/50
# 251/251 [==============================] - 43s 173ms/step - loss: 0.7292 - accuracy: 0.6961 - val_loss: 7.4603 - val_accuracy: 0.5012
# Epoch 6/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.6334 - accuracy: 0.7234 - val_loss: 2.7673 - val_accuracy: 0.6332
# Epoch 7/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.5529 - accuracy: 0.7458 - val_loss: 0.5816 - val_accuracy: 0.7385
# Epoch 8/50
# 251/251 [==============================] - 44s 174ms/step - loss: 0.5364 - accuracy: 0.7555 - val_loss: 0.4640 - val_accuracy: 0.7617
# Epoch 9/50
# 251/251 [==============================] - 44s 174ms/step - loss: 0.4955 - accuracy: 0.7680 - val_loss: 0.6319 - val_accuracy: 0.7711
# Epoch 10/50
# 251/251 [==============================] - 44s 177ms/step - loss: 0.4735 - accuracy: 0.7798 - val_loss: 0.3860 - val_accuracy: 0.7637
# Epoch 11/50
# 251/251 [==============================] - 45s 181ms/step - loss: 0.4603 - accuracy: 0.7916 - val_loss: 0.3300 - val_accuracy: 0.7519
# Epoch 12/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.4422 - accuracy: 0.7973 - val_loss: 1.4171 - val_accuracy: 0.6915
# Epoch 13/50
# 251/251 [==============================] - 45s 178ms/step - loss: 0.4358 - accuracy: 0.7970 - val_loss: 0.5999 - val_accuracy: 0.7820
# Epoch 14/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.4255 - accuracy: 0.8109 - val_loss: 1.9063 - val_accuracy: 0.6164
# Epoch 15/50
# 251/251 [==============================] - 44s 174ms/step - loss: 0.4174 - accuracy: 0.8101 - val_loss: 2.1171 - val_accuracy: 0.5892
# Epoch 16/50
# 251/251 [==============================] - 45s 178ms/step - loss: 0.4089 - accuracy: 0.8151 - val_loss: 0.6640 - val_accuracy: 0.7573
# Epoch 17/50
# 251/251 [==============================] - 44s 174ms/step - loss: 0.4370 - accuracy: 0.8039 - val_loss: 4.2264 - val_accuracy: 0.5284
# Epoch 18/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.4312 - accuracy: 0.8056 - val_loss: 0.5040 - val_accuracy: 0.7874
# Epoch 19/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.3990 - accuracy: 0.8165 - val_loss: 1.0374 - val_accuracy: 0.8087
# Epoch 20/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.3719 - accuracy: 0.8352 - val_loss: 1.0041 - val_accuracy: 0.7701
# Epoch 21/50
# 251/251 [==============================] - 44s 174ms/step - loss: 0.3770 - accuracy: 0.8365 - val_loss: 1.2452 - val_accuracy: 0.7400
# Epoch 22/50
# 251/251 [==============================] - 45s 178ms/step - loss: 0.4491 - accuracy: 0.7999 - val_loss: 0.9792 - val_accuracy: 0.7721
# Epoch 23/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.3746 - accuracy: 0.8346 - val_loss: 0.8235 - val_accuracy: 0.7781
# Epoch 24/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.3566 - accuracy: 0.8375 - val_loss: 0.5313 - val_accuracy: 0.8141
# Epoch 25/50
# 251/251 [==============================] - 44s 177ms/step - loss: 0.3475 - accuracy: 0.8481 - val_loss: 1.1721 - val_accuracy: 0.7603
# Epoch 26/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.3461 - accuracy: 0.8503 - val_loss: 1.0519 - val_accuracy: 0.7914
# Epoch 27/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.3432 - accuracy: 0.8507 - val_loss: 0.8173 - val_accuracy: 0.8008
# Epoch 28/50
# 251/251 [==============================] - 44s 177ms/step - loss: 0.3316 - accuracy: 0.8547 - val_loss: 3.0919 - val_accuracy: 0.5868
# Epoch 29/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.3403 - accuracy: 0.8492 - val_loss: 0.9598 - val_accuracy: 0.8369
# Epoch 30/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.3430 - accuracy: 0.8500 - val_loss: 0.6560 - val_accuracy: 0.8285
# Epoch 31/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.3134 - accuracy: 0.8601 - val_loss: 1.3349 - val_accuracy: 0.8003
# Epoch 32/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.3158 - accuracy: 0.8658 - val_loss: 1.2908 - val_accuracy: 0.7954
# Epoch 33/50
# 251/251 [==============================] - 44s 174ms/step - loss: 0.3195 - accuracy: 0.8620 - val_loss: 0.4883 - val_accuracy: 0.8211
# Epoch 34/50
# 251/251 [==============================] - 45s 179ms/step - loss: 0.3152 - accuracy: 0.8641 - val_loss: 0.8873 - val_accuracy: 0.8369
# Epoch 35/50
# 251/251 [==============================] - 43s 173ms/step - loss: 0.3091 - accuracy: 0.8655 - val_loss: 0.4044 - val_accuracy: 0.8458
# Epoch 36/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.3015 - accuracy: 0.8712 - val_loss: 1.2435 - val_accuracy: 0.7637
# Epoch 37/50
# 251/251 [==============================] - 45s 178ms/step - loss: 0.3389 - accuracy: 0.8578 - val_loss: 1.4159 - val_accuracy: 0.7677
# Epoch 38/50
# 251/251 [==============================] - 44s 176ms/step - loss: 0.2901 - accuracy: 0.8746 - val_loss: 0.6368 - val_accuracy: 0.8359
# Epoch 39/50
# 251/251 [==============================] - 43s 173ms/step - loss: 0.3068 - accuracy: 0.8695 - val_loss: 0.6436 - val_accuracy: 0.8502
# Epoch 40/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.2883 - accuracy: 0.8807 - val_loss: 1.1148 - val_accuracy: 0.8285
# Epoch 41/50
# 251/251 [==============================] - 43s 173ms/step - loss: 0.2887 - accuracy: 0.8730 - val_loss: 0.7759 - val_accuracy: 0.8364
# Epoch 42/50
# 251/251 [==============================] - 43s 172ms/step - loss: 0.2848 - accuracy: 0.8728 - val_loss: 1.9462 - val_accuracy: 0.6782
# Epoch 43/50
# 251/251 [==============================] - 44s 175ms/step - loss: 0.2888 - accuracy: 0.8765 - val_loss: 0.9498 - val_accuracy: 0.7781
# Epoch 44/50
# 251/251 [==============================] - 44s 174ms/step - loss: 0.2804 - accuracy: 0.8790 - val_loss: 0.9748 - val_accuracy: 0.8438
# Epoch 45/50
# 251/251 [==============================] - 43s 173ms/step - loss: 0.2740 - accuracy: 0.8798 - val_loss: 0.3289 - val_accuracy: 0.8408
# Epoch 46/50
# 251/251 [==============================] - 44s 177ms/step - loss: 0.2702 - accuracy: 0.8834 - val_loss: 0.9552 - val_accuracy: 0.8349
# Epoch 47/50
# 251/251 [==============================] - 43s 173ms/step - loss: 0.2732 - accuracy: 0.8819 - val_loss: 0.6988 - val_accuracy: 0.8448
# Restoring model weights from the end of the best epoch
# Epoch 00047: early stopping

# %% [markdown]
# ## Evaluation

# %%
train_acc = model.evaluate(train_data)
test_acc = model.evaluate(test_data)
# Out:
# 251/251 [==============================] - 35s 140ms/step
# 64/64 [==============================] - 9s 138ms/step

# %% [markdown]
# ## Results

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 10))
ax1.plot(history.history['loss'], color='b', label="Training loss : {:0.4f}".format(train_acc[0]))
ax1.plot(history.history['val_loss'], color='r', label="validation loss : {:0.4f}".format(test_acc[0]))
ax1.legend()

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy : {0:.4f}".format(train_acc[1]))
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy : {0:.4f}".format(test_acc[1]))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Testing Visualization

# %%
test_paths = np.array(glob(TEST_DIR + '/*/*.jpg'))

np.random.seed(42)
ids = np.random.choice(np.arange(len(test_paths)), size=32)

samples = test_paths[ids]

# %%
im_test = []
c = 0
for img in samples:
    c = c + 1
    img_path =img
    img_arr = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img_arr = cv2.resize(img_arr, (IMGSIZE, IMGSIZE))
    img_arr = img_arr / 255.0
    im_test.append(img_arr)

    
im_test = np.array(im_test).reshape(-1, IMGSIZE, IMGSIZE, 1)
im_pred = model.predict(im_test)

# %%
fig , ax = plt.subplots(4, 4, figsize=(30, 25))

for i, axis in enumerate(ax.flat):
    axis.imshow(im_test[i][:, :, 0], cmap='gray')
    pred_class = im_pred[i].argmax()
    pred_prob = im_pred[i].max() * 100

    axis.set_title(f'Predict: {category[pred_class]}\n Confidence: {pred_prob:.1f}%', fontsize=18)

# %%
# save the model weights
model.save_weights(MODEL_NAME)

# %% [markdown]
# ## Other Solution:
#
# Rather than using your custom CNN network, you can use a pretrained model.
# This method called **Transfer Learning**.
#
# check out how to implement it: **[Transfer Learning (CATs vs DOGs)](https://www.kaggle.com/code/elcaiseri/transfer-learning-cat-vs-dog)**

# %% [markdown]
# ### If you like, <span style='color:red'>UPVOTE</span> it. feel free to ask me anything in the comment section.
